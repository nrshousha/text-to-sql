# %%
import sys
sys.path.append('..')  # so we can import from app/ even though the notebook lives in notebooks/

from app.db import execute_query

# %%
execute_query("SELECT * FROM products;")
# Out:
# [{'id': 2,
#   'name': 'Cardboard Box Medium',
#   'sku': 'BOX-MED-002',
#   'quantity_on_hand': 200,
#   'reorder_threshold': 50},
#  {'id': 3,
#   'name': 'Packing Tape Roll',
#   'sku': 'TAPE-001',
#   'quantity_on_hand': 30,
#   'reorder_threshold': 40},
#  {'id': 1,
#   'name': 'Steel Bolt M6',
#   'sku': 'BLT-M6-001',
#   'quantity_on_hand': 495,
#   'reorder_threshold': 100}]

# %%
execute_query("UPDATE products SET quantity_on_hand = 495 WHERE sku = 'BLT-M6-001';")
# Out:
# []

# %%
execute_query("SELECT quantity_on_hand FROM products WHERE sku = 'BLT-M6-001';")
# Out:
# [{'quantity_on_hand': 495}]
